# %% [markdown]
# # ch5

# %%
dec_2m = 2_000_000
dec_2m

# %%
help(hex)

# hex_val -> encoding(hex_val) -> character

some_dec = int(0x1F600) # dec

# dec -> encode? -> charcter

# ascii(some_dec)
# int(some_dec)b

# %%
print("\U0001F600")

# %%
c = chr(0x1F600)
print(c)
print(ord(c))
print(hex(ord(c)))

# %%
c = chr(0x1F600)
print(ord(c))
# print(c.)
# bytes()
# (int(0x1F600)).to_bytes()
# .to_bytes()
# Out:
# 128512
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[14], line 5
#       2 print(ord(c))
#       3 # print(c.)
#       4 # bytes()
# ----> 5 (int(0x1F600)).to_bytes()
#       6 # .to_bytes()
#
# OverflowError: int too big to convert

# %%
16**4+15*16**3+6*16**2
# Out:
# 128512

# %%
15*16
# Out:
# 240
