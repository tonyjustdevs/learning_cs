# %% [markdown]
# # Speaking C#
#
# # 1. Introducing C#
# - `dotnet --version`: sdk version

# %% [markdown]
# # 2. C# Compiler Version
# `#error version` - compile.

# %% [markdown]
# # 3. C# Gramma
#
# # 3.1 Autogenerated implicit imports file
# File: `/ProjectName.GlobalUsings.g.cs`
# Folder: `ProjectName/obj/Debug/net9.0/`
#
#     <Using Remove="System.Threading" />
#     <Using Include="System.Numerics" />
#     <Using Include="System.Console" Static="true" />
#     <Using Include="System.Environment" Alias="Env" />
#
# `Env.MachineName` working now due to implicity imports of

# %% [markdown]
# # 3.2 Namespaces are implicitly imported
# `Env.MachineName` variable works because above:
#
# - statically imported `Console` class
# - aliased Environment class `Env`

# %% [markdown]
# # 4. Variables
# `nameof(variable)`: to output name of variable

# %% [markdown]
# # 5. Console Apps
# # 6. Exploration
# # 7. Summary
