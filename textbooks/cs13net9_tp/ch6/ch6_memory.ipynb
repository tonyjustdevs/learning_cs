# %% [markdown]
# # Ch6: Memory
#
# Reference:
#
# - https://github.com/markjprice/cs14net10/blob/main/docs/ch06-memory.md
#
# **Topics**:
#
# - Understanding stack and heap memory
# - Defining reference and value types
# - How reference and value types are stored in memory
# - Understanding boxing
# - Defining struct types
# - Defining record struct types
# - Releasing unmanaged resources
# - Ensuring that Dispose is called

# %% [markdown]
# # 1. How Reference & Value Types Are Stored In Memory
# ## 1.1 Console App: Scenario
# Imagine a ConsoleApp:
#
# - ***calls*** `SomeMethod()` (see below)
# - `SomeMethod()` has:
#     - **ref** &
#     - **val** type variables

# %% [markdown]
# ## 1.2 `SomeMethod()` CSharp Code

# %%
void SomeMethod() # csharp code example
    { 
        int number1 = 49;
        long number2 = 12;
        System.Drawing.Point location = new(x: 3, y: 5);

        Person kevin = new() { Name = "Kevin",
            Born = new(1988, 9, 23, 0, 0, 0, TimeSpan.Zero) };

        Person sally;
    }
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.vevn (3.13.3) (Python 3.13.3)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 1.3 Type Variable Memory Storage
# The table below shows where memory is allocated when this method is executed on the:
#
# - stack &
# - heap

# %% [markdown]
# | variable | type | allocated | bytes |
# | -------- | ---- | --------- | ----- |
# | -------- | ---- | --------- | ----- |
